# %% [markdown]
# # Summer School: Digitale Methoden der Zeitungsanalyse
#
# Dieses Jupyter Notebook zeigt, wie Zeitungstitel (am Beispiel der Zeitung „[La otra Alemania](https://www.deutsche-digitale-bibliothek.de/newspaper/2149754-0)“) aus dem Zeitungsportal über die Programmierschnittstelle (API) der Deutschen Digitale Bibliothek heruntergeladen werden können. Dazu werden Aspekte der API erklärt und der Zugriff mit Python-Programmcode demonstriert.
#
# ## Suchindizes der Deutsche Digitale Bibliothek
# Die Deutsche Digitale Bibliothek betreibt [Solr](https://solr.apache.org/guide/8_8/searching.html)-Suchindizes, die für die verschiedenen Funktionen der (Sub-) Portale benötigt werden. Das Zeitungsportal benutzt zwei Suchindizes. Eine weiterführende Dokumentation befindet sich hier: https://api.deutsche-digitale-bibliothek.de/#/search/getSolrSearch
#
# - `newspaper`: enthält Informationen über Zeitungstitel
#   - Schema: https://dev.fiz-karlsruhe.de/stash/projects/DDB/repos/ddb-backend/browse/Cortex/conf/solr/newspaper/conf/schema.xml
#   - Konfiguration: https://dev.fiz-karlsruhe.de/stash/projects/DDB/repos/ddb-backend/browse/Cortex/conf/solr/newspaper/conf/solrconfig.xml
# - `newspaper-issues`: enthält die zeitungsbezogenen Metadaten inkl. Volltexte
#   - Schema: https://dev.fiz-karlsruhe.de/stash/projects/DDB/repos/ddb-backend/browse/Cortex/conf/solr/newspaper-issues/conf/schema.xml
#   - Konfiguration: https://dev.fiz-karlsruhe.de/stash/projects/DDB/repos/ddb-backend/browse/Cortex/conf/solr/newspaper-issues/conf/solrconfig.xml
#
# ## Suchindex `newspaper`
# Der Suchindex `newspaper` ist ein Suchindex über alle Zeitungstitel der [Zeitschriftendatenbank (ZDB)](https://zdb-katalog.de/). Im Schema des Suchindex (s.o.) sind die Suchfelder (Facetten) dokumentiert. Wenn Zeitungstitel gefunden werden sollen, die im Zeitungsportal verfügbar sind, dann muss nach `hasLoadedIssues:true` (Feld:Wert) gesucht werden.
#
# - https://api.deutsche-digitale-bibliothek.de/2/search/index/newspaper/select?q=hasLoadedIssues:true
#
# Die Suchfelder können beliebig miteinander kombiniert werden. Das geht mit den Operatoren `AND` und `OR`. Möchte man beispielsweise Zeitungen mit „La otra Alemania“ im Titel suchen, die auch im Zeitungsportal verfügbar sind, dann kombiniert man: `hasLoadedIssues:true AND title:"La otra Alemania"`
#
# - [https://api.deutsche-digitale-bibliothek.de/2/search/index/newspaper/select?q=hasLoadedIssues:true AND title:"La otra Alemania"](https://api.deutsche-digitale-bibliothek.de/2/search/index/newspaper/select?q=hasLoadedIssues:true%20AND%20title:"La+otra+Alemania")
#
# ### Python-Programmcode
#
# Python-Programmcode in Jupyter Notebooks ermöglicht interaktives Programmieren und sofortige Anzeige von Ergebnissen. Es ist ideal für die Datenanalyse und Visualisierungen. Python-Bibliotheken können in Notebooks nachgenutzt werden und erhöhen so den Funktionsumfang.
#
# Die o. g. Solr-Abfrage kann mit Python ausgeführt werden (Bibliothek [`requests`](https://pypi.org/project/requests/)) und die Antwort von der API mit einem JSON-Parser (`json`) gelesen werden. Eine andere Möglichkeit ist, den Solr-Client [`pysolr`](https://pypi.org/project/pysolr/) zu benutzen. Dieser muss zunächst in der Umgebung mit `pip install -q pysolr` (oder ggf. mit Conda: `conda install conda-forge::pysolr`) installiert werden.

# %%
# Python-Bibliothek pysolr installieren
# %pip install -q pysolr
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### KI-generierter Programmcode
#
# Die Erstellung des Python-Programmcodes ist KI-gestützt möglich. Die folgenden KI-Prompts sind mit ChatGPT (GPT-4o) erfolgreich getestet und liefern (oft 😉) das gewünschte Ergebnis.
#
# <div class="alert alert-block alert-info">
# <b>Prompt:</b> Ich möchte in Python mit dem Solr-Client <code>pysolr</code> auf den Endpunkt <code>https://api.deutsche-digitale-bibliothek.de/2/search/index/newspaper</code> zugreifen. Kannst Du mir einen Python-Code erstellen, der im Feld <code>location</code> nach „Buenos Aires“ sucht und auch <code>hasLoadedIssues</code> auf „wahr“ setzt. Gibt bitte <code>id</code>, <code>title</code>, <code>location</code>, <code>frequency</code> und <code>progress</code> für jeden Suchtreffer aus.
# </div>

# %%
import pysolr

# Solr-Endpunkt-URL
solr_url = 'https://api.deutsche-digitale-bibliothek.de/2/search/index/newspaper'

# Solr-Client initialisieren
solr = pysolr.Solr(solr_url, timeout=10)

# Suchparameter
q = {
    'q': 'location:"buenos aires" AND hasLoadedIssues:true',
    'fl': 'id,title,location,frequency,progress',
    'rows': 10  # Anzahl der zurückzugebenden Ergebnisse
}

# Suche ausführen
results = solr.search(**q)

# Ergebnisse ausgeben
for result in results:
    print(f"ID: {result.get('id', 'N/A')}")
    print(f"Title: {result.get('title', 'N/A')}")
    print(f"Location: {result.get('location', 'N/A')}")
    print(f"Frequency: {result.get('frequency', 'N/A')}")
    print(f"Progress: {result.get('progress', 'N/A')}")
    print("-" * 40)
# Out:
# ID: 2232340-5
# Title: ['Das andere Deutschland']
# Location: ['Buenos Aires']
# Frequency: ['http://id.loc.gov/vocabulary/frequencies/mon']
# Progress: ['[1.]1937/38,Juli-Dez.=Nr. 3-8; 2.1939,Jan. - 5.1941,Dez. = Nr. 9-45; mehr nicht digitalisiert']
# ----------------------------------------
# ID: 2149754-0
# Title: ['La otra Alemania']
# Location: ['Montevideo', 'Buenos Aires']
# Frequency: ['http://id.loc.gov/vocabulary/frequencies/irr']
# Progress: ['5.1942,Jan. - 6.1943,15.Dez. = Nr. 46-79; [N.F.] 1.1944,1/2(Febr.)-3/4(März); 7.1944/45,Apr.-15.Dez.=Nr. 80/81-108; 8.1946,1.Jan.-15.Aug.=Nr. 109-124; 1946,1.Sept. - 1949,Jan. = Nr. 125-175; damit Ersch. eingest.']
# ----------------------------------------

# %% [markdown]
# ## Suchindex `newspaper-issues`
#
# Der Suchindex `newspaper-issues` ist ein weiterer Suchindex des Zeitungsportals. Dieser enthält alle Ausgaben (`type:issue`) einer Zeitung und alle Seiten (`type:page`). Wenn man nur in einem Zeitungstitel suchen möchte, so kann dies über `zdb_id:{ID der Zeitschriftendatenbank}` (für die „La otra Alemania“ ist es `zdb_id:2149754-0`) eingegrenzt werden.
#
# ### KI-generierter Programmcode
#
# <div class="alert alert-block alert-info">
# <b>Prompt:</b> Schreibe ein Python-Code, der mithilfe der <code>pysolr</code>-Bibliothek eine Suche in einem Solr-Index durchführt und die Ergebnisse in ein Pandas DataFrame überführt. Der Solr-Index ist über die URL <code>https://api.deutsche-digitale-bibliothek.de/2/search/index/newspaper-issues</code> erreichbar. Die Suchabfrage soll nach Dokumenten mit der <code>zdb_id</code> „2149754-0“ und dem <code>type</code> „issue“ suchen und bis zu 1000 Ergebnisse zurückgeben. Anschließend sollen die Ergebnisse in ein Pandas DataFrame überführt und angezeigt werden.
# </div>

# %%
# Python-Bibliothek pandas installieren
# %pip install -q pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

solr_url = 'https://api.deutsche-digitale-bibliothek.de/2/search/index/newspaper-issues'
solr = pysolr.Solr(solr_url, always_commit=True, timeout=10)

q = {
    'q': 'zdb_id:2149754-0 AND type:issue',
    'rows': 1000
}

response = solr.search(**q)
    
# Überführen der Ergebnisse in ein Pandas DataFrame
df = pd.DataFrame(response.docs)

# DataFrame anzeigen
df
# Out:
#                                    id  \
# 0    ZYOWCJLQOY4U2C5DXWWX22WYDP5PQJT3
# 1    MMZANT7CHYIXHM2E63NLTPIQL5VWGIFX
# 2    GCADKIMUKSSL23LL6BXHWRNP66KQR37R
# 3    S3LEVONENQZ7BAICDWHE7L2LPJ6IJYD2
# 4    QC2SMVMRK67PTHDQW65FLNUCUOWUO2UV
# ..                                ...
# 124  HHJX6JF6XZXGNA22FSHKMDDVP5KATS4J
# 125  SZXP6GEGBOD42J5TKYQ64XNDTUJO2S77
# 126  CAMRPRGLRHFMUJFGTVKX4RW5KJTRR5LT
# 127  DGJVAWT6K23ZQ5TVOSAKADSDJSSYQV3V
# 128  BA5FYSSHUMOEXBAZHFQMT4LI3V4VBQBA
#
#                                            paper_title  \
# 0    La otra Alemania : órgano de los alemanes demo...
# 1    La otra Alemania : órgano de los alemanes demo...
# 2    La otra Alemania : órgano de los alemanes demo...
# 3    La otra Alemania : órgano de los alemanes demo...
# 4    La otra Alemania : órgano de los alemanes demo...
# ..                                                 ...
# 124  La otra Alemania : órgano de los alemanes demo...
# 125  La otra Alemania : órgano de los alemanes demo...
# 126  La otra Alemania : órgano de los alemanes demo...
# 127  La otra Alemania : órgano de los alemanes demo...
# 128  La otra Alemania : órgano de los alemanes demo...
#
#                       provider_ddb_id              provider     zdb_id  \
# 0    UJVQP2TIF4YVCCJQXWZ2BNEECO7ZHYTW  Deutsches Exilarchiv  2149754-0
# 1    UJVQP2TIF4YVCCJQXWZ2BNEECO7ZHYTW  Deutsches Exilarchiv  2149754-0
# 2    UJVQP2TIF4YVCCJQXWZ2BNEECO7ZHYTW  Deutsches Exilarchiv  2149754-0
# 3    UJVQP2TIF4YVCCJQXWZ2BNEECO7ZHYTW  Deutsches Exilarchiv  2149754-0
# 4    UJVQP2TIF4YVCCJQXWZ2BNEECO7ZHYTW  Deutsches Exilarchiv  2149754-0
# ..                                ...                   ...        ...
# 124  UJVQP2TIF4YVCCJQXWZ2BNEECO7ZHYTW  Deutsches Exilarchiv  2149754-0
# 125  UJVQP2TIF4YVCCJQXWZ2BNEECO7ZHYTW  Deutsches Exilarchiv  2149754-0
# 126  UJVQP2TIF4YVCCJQXWZ2BNEECO7ZHYTW  Deutsches Exilarchiv  2149754-0
# 127  UJVQP2TIF4YVCCJQXWZ2BNEECO7ZHYTW  Deutsches Exilarchiv  2149754-0
# 128  UJVQP2TIF4YVCCJQXWZ2BNEECO7ZHYTW  Deutsches Exilarchiv  2149754-0
#
#      ns_disclaimer_required      publication_date       place_of_distribution  \
# 0                     False  1945-06-15T12:00:00Z  [Montevideo, Buenos Aires]
# 1                     False  1944-06-01T12:00:00Z  [Montevideo, Buenos Aires]
# 2                     False  1947-04-15T12:00:00Z  [Montevideo, Buenos Aires]
# 3                     False  1944-04-25T12:00:00Z  [Montevideo, Buenos Aires]
# 4                     False  1943-03-01T12:00:00Z  [Montevideo, Buenos Aires]
# ..                      ...                   ...                         ...
# 124                   False  1947-07-01T12:00:00Z  [Montevideo, Buenos Aires]
# 125                   False  1945-10-01T12:00:00Z  [Montevideo, Buenos Aires]
# 126                   False  1943-12-15T12:00:00Z  [Montevideo, Buenos Aires]
# 127                   False  1947-10-01T12:00:00Z  [Montevideo, Buenos Aires]
# 128                   False  1947-11-15T12:00:00Z  [Montevideo, Buenos Aires]
#
#        language                             thumbnail
# 0    [spa, ger]  80cc1929-c89b-4bdf-854d-59b2cab45496
# 1    [spa, ger]  fe845673-fd4f-4da4-975d-02c54743b76a
# 2    [spa, ger]  cd7057bb-5d83-449d-a8c5-afa5c1769e8e
# 3    [spa, ger]  9e7862fc-e09a-49c5-999c-b7c5f45ec3b6
# 4    [spa, ger]  415e6569-a480-4d25-a2b1-b61202f24f9f
# ..          ...                                   ...
# 124  [spa, ger]  b7c6b3cc-1a27-4410-a0d7-c24f7c732d67
# 125  [spa, ger]  9146f0e1-7d4c-473b-9876-056490e778c0
# 126  [spa, ger]  6f77dacd-03c5-4160-b71d-4280f5493099
# 127  [spa, ger]  1e6f3bf9-dcb7-42bd-8416-bafd35212352
# 128  [spa, ger]  88984bd2-efbb-4e57-8582-2198caaa3098
#
# [129 rows x 10 columns]

# %% [markdown]
# ### Erste Datenanalyse
#
# In dem Dataframe können nun Datenanalysen vorgenommen werden. Wir wollen den Publikationszeitraum von der Zeitung „La otra Alemania“ ermitteln.

# %%
# Sicherstellen, dass publication_date als Datumswerte formatiert sind
df['publication_date'] = pd.to_datetime(df['publication_date'])

# Frühestes und spätestes Datum ermitteln
earliest_date = df['publication_date'].min()
latest_date = df['publication_date'].max()

# Ergebnisse anzeigen
print(f"Frühestes Veröffentlichungsdatum: {earliest_date}")
print(f"Spätestes Veröffentlichungsdatum: {latest_date}")
# Out:
# Frühestes Veröffentlichungsdatum: 1942-01-01 12:00:00+00:00
# Spätestes Veröffentlichungsdatum: 1949-01-01 12:00:00+00:00

# %% [markdown]
# ## Download der METS/MODS-Daten
#
# Im Deutschen Zeitungsportal ist jede Zeitungsausgabe durch eine METS/MODS-Datei repräsentiert. Diese beinhaltet Links zu den Bild- und Volltextseiten sowie weitere Informationen.
#
# > METS ([Metadata Encoding and Transmission Standard](https://www.loc.gov/standards/mets/)) und MODS ([Metadata Object Description Schema](https://www.loc.gov/standards/mods/)) sind zwei miteinander verbundene Metadatenformate, die häufig in Bibliotheken und Archiven verwendet werden.
# >
# > METS ist ein XML-basiertes Format, das zur Kodierung und Übertragung von Metadaten für digitale Bibliotheksobjekte entwickelt wurde. Es dient als Container, der verschiedene Arten von Metadaten und die strukturellen Beziehungen zwischen den Teilen eines digitalen Objekts beschreibt. Es besteht aus mehreren Abschnitten wie `metsHdr` (Header), `fileSec` (Dateien), `structMap` (Struktur) und `metadataSec` (Metadatensektion).
# >
# > MODS ist ebenfalls ein XML-basiertes Format, das zur Erfassung und zum Austausch bibliografischer Informationen entwickelt wurde. Es bietet Elemente wie `titleInfo` (Titelinformation), `name` (Namen), `originInfo` (Herkunftsinformationen), und `subject` (Themen).
#
# Auf die METS/MODS-Daten kann über die [API-Methode](https://labs.deutsche-digitale-bibliothek.de/app/ddbapi/#/items/getItemsIdSourceComponent) `items/{id}/source/record` zugegriffen werden. Dafür muss die DDB-ID der Zeitungsausgabe bekannt sein, die wir im vorhergehenden Schritt (bspw. `ZYOWCJLQOY4U2C5DXWWX22WYDP5PQJT3`) ermittelt haben. Damit ergibt sich folgende API-Abfrage:
#
# - https://api.deutsche-digitale-bibliothek.de/2/items/ZYOWCJLQOY4U2C5DXWWX22WYDP5PQJT3/source/record
#
# ### KI-generierter Programmcode
# <div class="alert alert-block alert-info">
# <b>Prompt:</b> Erstelle mit Python ein Verzeichnis <code>La_Otra_Alemania</code>, in dem heruntergeladene XML-Dateien gespeichert werden können. Iteriere durch jede Zeile des bestehenden DataFrames <code>df</code>, der die Spalten <code>id</code> und <code>publication_date</code> enthält.
# Für jede Zeile:
# <ol>
#   <li>Extrahiere den Wert der Spalte <code>id</code>.</li>
#   <li>Formatiere den ISO-DateTime-Wert der Spalte <code>publication_date</code> im Format <code>YYYY-MM-DD</code>.</li>
#   <li>Generiere eine URL <code>https://api.deutsche-digitale-bibliothek.de/2/items/{id}/source/record</code> zur API-Abfrage</li>
#   <li>Setze die HTTP-Header so, dass die Antwort im XML-Format akzeptiert wird.</li>
#   <li>Erstelle einen Dateipfad für die XML-Datei im Format <code>{publication_date}_{id}.xml</code> und speichere sie im erstellten Verzeichnis.</li>
# </ol>
# </div>

# %%
# Python-Bibliothek requests installieren
# %pip install -q requests
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import requests

# Verzeichnis für die XML-Dateien erstellen
directory = 'La_Otra_Alemania'
if not os.path.exists(directory):
    os.makedirs(directory)

# Durch jede Zeile des DataFrames iterieren
for index, row in df.iterrows():
    # Extrahiere den Wert der Spalte id
    item_id = row['id']
    
    # Formatiere den Wert der Spalte publication_date im Format YYYY-MM-DD
    publication_date = row['publication_date'].strftime('%Y-%m-%d')
    
    # Generiere die URL zur API-Abfrage
    url = f'https://api.deutsche-digitale-bibliothek.de/2/items/{item_id}/source/record'
    
    # Setze die HTTP-Header
    headers = {
        'Accept': 'application/xml'
    }
    
    # API-Anfrage senden
    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        # Erstelle einen Dateipfad für die XML-Datei
        file_path = os.path.join(directory, f'{publication_date}_{item_id}.xml')
        
        # Speichere die XML-Datei im erstellten Verzeichnis
        with open(file_path, 'wb') as file:
            file.write(response.content)
        print(f'Datei gespeichert: {file_path}')
    else:
        print(f'Fehler beim Abrufen der Datei für ID {item_id}: {response.status_code}')

print('Fertig!')
# Out:
# Datei gespeichert: La_Otra_Alemania\1945-06-15_ZYOWCJLQOY4U2C5DXWWX22WYDP5PQJT3.xml
# Datei gespeichert: La_Otra_Alemania\1944-06-01_MMZANT7CHYIXHM2E63NLTPIQL5VWGIFX.xml
# Datei gespeichert: La_Otra_Alemania\1947-04-15_GCADKIMUKSSL23LL6BXHWRNP66KQR37R.xml
# Datei gespeichert: La_Otra_Alemania\1944-04-25_S3LEVONENQZ7BAICDWHE7L2LPJ6IJYD2.xml
# Datei gespeichert: La_Otra_Alemania\1943-03-01_QC2SMVMRK67PTHDQW65FLNUCUOWUO2UV.xml
# Datei gespeichert: La_Otra_Alemania\1946-12-01_R447FYT3N4GHLXMZ57UMCK2J33IHLSKD.xml
# Datei gespeichert: La_Otra_Alemania\1943-12-01_RESVDPWSQMDVMSCLT6BC2XO5FIO2CWP7.xml
# Datei gespeichert: La_Otra_Alemania\1947-12-15_KYFSYF4D2OKSDBQJ2P56UKSTOOT74Q32.xml
# Datei gespeichert: La_Otra_Alemania\1947-03-01_2ZEPATYNE5HIR3L2FLJMNA4G7PHJXJWT.xml
# Datei gespeichert: La_Otra_Alemania\1948-01-01_QTWE5X2JKYKT2LOIZWKQQ536GUMZX7XT.xml
# Datei gespeichert: La_Otra_Alemania\1943-08-01_SYPEUU7HVBAAZS6W3HCUQSJWSY4B5YAZ.xml
# Datei gespeichert: La_Otra_Alemania\1944-03-01_UHYDLNVBLM2HINLPULBQRS3LN6KCUDSL.xml
# Datei gespeichert: La_Otra_Alemania\1944-05-25_3XN2ES5IDZCJ3G5X6KYMV2UILMJK2EHQ.xml
# Datei gespeichert: La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO.xml
# Datei gespeichert: La_Otra_Alemania\1942-10-01_PAY242WL5USOOG3KC75Q5OKYTYMFBG7U.xml
# Datei gespeichert: La_Otra_Alemania\1948-04-15_PDIA7RYTJLJ37KVYY422YZOG3EVFAITZ.xml
# Datei gespeichert: La_Otra_Alemania\1944-12-01_6NEXCGDMKEPL4SVSZJCBVXAP7MIQRHRU.xml
# Datei gespeichert: La_Otra_Alemania\1945-12-15_V7A3VPUEC46AB3OEQAYW6PKOQMO36T4P.xml
# Datei gespeichert: La_Otra_Alemania\1948-12-01_AK26JXHRHC2T72IMFGUAJ7EIFJQLY4CL.xml
# Datei gespeichert: La_Otra_Alemania\1946-07-15_6JQ7GVLHN7FMK4THCWQN3ZDAVT2CLK56.xml
# Datei gespeichert: La_Otra_Alemania\1943-09-15_TY7KQGWIOCB64ZGDE3E6QE7EX6BUANWV.xml
# Datei gespeichert: La_Otra_Alemania\1948-05-01_LVQZNU2GQY4R3QSFPFEHBHEINPS2SX3P.xml
# Datei gespeichert: La_Otra_Alemania\1943-12-15_VKIUGVARJF6PNFPIGE6ZLFA4PJTBWXLX.xml
# Datei gespeichert: La_Otra_Alemania\1943-12-15_ZLRBGXURU5ZHHOJCHHCPW6IBNAZ3YDVP.xml
# Datei gespeichert: La_Otra_Alemania\1947-04-01_ZLMTHRV2VTVMBEMMZN6OECONUAFKUPCC.xml
# Datei gespeichert: La_Otra_Alemania\1946-08-15_VW3CWIRJ6PRSIFUNHMGHVYT4QE5AO6J6.xml
# Datei gespeichert: La_Otra_Alemania\1943-06-15_5QFLZVEML3GNA7GSVWNGPJIQJDLRJMKE.xml
# Datei gespeichert: La_Otra_Alemania\1942-12-01_N4ILVLVMBU5KZ2SUQTAI467GXXG3HWMR.xml
# Datei gespeichert: La_Otra_Alemania\1944-11-01_JMQFC62AY2Z7PXD3GGAE6AC7YPGIC7VL.xml
# Datei gespeichert: La_Otra_Alemania\1942-07-01_LJ5BPAX4ZT4KQ3IUDPOSRFBJ2FKVSVNP.xml
# Datei gespeichert: La_Otra_Alemania\1947-12-01_5J74HSHVBOFYYDA6ELF43576WRL5ZMQ6.xml
# Datei gespeichert: La_Otra_Alemania\1943-09-01_FJSGE52CV7MNSAXS5ZKRZMUSKWEEWVPQ.xml
# Datei gespeichert: La_Otra_Alemania\1943-06-01_QOEMYDWQJZX6ZELOB3QBBDHCSSLDVQWU.xml
# Datei gespeichert: La_Otra_Alemania\1949-01-01_JSA23G54JQZMR3ZQGRTAGZBBMMXGS3ZA.xml
# Datei gespeichert: La_Otra_Alemania\1945-11-01_SVILJKRE4RGFDQ2I67ISTCWQ7FWUPTMB.xml
# Datei gespeichert: La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5.xml
# Datei gespeichert: La_Otra_Alemania\1945-08-15_RL564YAER6RHTI2OCGVMWUOUG53ZJRGM.xml
# Datei gespeichert: La_Otra_Alemania\1946-11-15_QB7K5BKBZLWBF5GUNHWS3IXDF25AIZGH.xml
# Datei gespeichert: La_Otra_Alemania\1947-11-01_C64GMZLKKPLFHPXRP7E6AI7L5KZBZAKH.xml
# Datei gespeichert: La_Otra_Alemania\1946-04-01_XH5D7MEXRH5MFIYJBCNTTE4SUAWPKYQ3.xml
# Datei gespeichert: La_Otra_Alemania\1943-02-01_XWNSILXL3GWJALMJYCGL5T5MIV7ULT4Q.xml
# Datei gespeichert: La_Otra_Alemania\1943-07-01_4GYOGDYU7WNIFZT3ZGOXCU46NSZTNTH3.xml
# Datei gespeichert: La_Otra_Alemania\1942-11-01_WS6FQSJZP2BAGAKX4755JMTQIEZX6ALH.xml
# Datei gespeichert: La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT.xml
# Datei gespeichert: La_Otra_Alemania\1944-10-01_X7A6Z4KWJDNZX6NNFNKPBLMZ35J7IT5J.xml
# Datei gespeichert: La_Otra_Alemania\1943-12-15_WYXAVMFRB4H2C6LFQFGCMVRBAYSDX5KY.xml
# Datei gespeichert: La_Otra_Alemania\1944-02-15_MBQBONZDMJWQKY5HHYF7CPEQFTJIQNYV.xml
# Datei gespeichert: La_Otra_Alemania\1948-01-15_QWRRQMWUJZKTBNNB47MHQSXM5RFEBZHP.xml
# Datei gespeichert: La_Otra_Alemania\1945-11-15_YROFAF3FSEP4AZVYFBZPSGQ55IRSHI6X.xml
# Datei gespeichert: La_Otra_Alemania\1945-08-01_YH4IRTDZ2YPXVONMNOEAQ3QGFEXUKVQI.xml
# Datei gespeichert: La_Otra_Alemania\1945-01-01_QEDPQWN4EXSAECTK3TDJ6KNKBCXCLVDA.xml
# Datei gespeichert: La_Otra_Alemania\1943-04-01_M3RQ2MXZFORPDLNXQA57XR6C5MNN3EFS.xml
# Datei gespeichert: La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU.xml
# Datei gespeichert: La_Otra_Alemania\1945-04-01_2KBIGMV5K3DQBRGEHBP7COFVB3JDA3JL.xml
# Datei gespeichert: La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC.xml
# Datei gespeichert: La_Otra_Alemania\1946-09-15_Z7MYBNWNND4BA3DR2REOAUFVXM443PRB.xml
# Datei gespeichert: La_Otra_Alemania\1947-10-15_WOBJJ66BZTGKKF334LUCOSI74U3H4WLB.xml
# Datei gespeichert: La_Otra_Alemania\1943-01-01_XFOGZGXPU7XNDRX5IDIBLA5SI52QAXYL.xml
# Datei gespeichert: La_Otra_Alemania\1946-03-01_VWLAGG7IDNNUVNBNY3QHNYZ2JECAJMBH.xml
# Datei gespeichert: La_Otra_Alemania\1945-05-15_IOYA6MZCUT4EFFUU4MDYWYGZ5UIZWSAF.xml
# Datei gespeichert: La_Otra_Alemania\1948-02-01_K6VFJM2RQ7CN5ZXHOYUF2J7STMZ3TFBG.xml
# Datei gespeichert: La_Otra_Alemania\1945-07-15_FFR73JAX2IAY2PKAJXGGQBO6SILITFLM.xml
# Datei gespeichert: La_Otra_Alemania\1942-09-01_CLUA7OMA4A647U4VEVTYEMKVF3RE2B4G.xml
# Datei gespeichert: La_Otra_Alemania\1947-07-15_4LE47LQRRVCLDEYPLAFUBIGDBGCDLDU5.xml
# Datei gespeichert: La_Otra_Alemania\1948-05-15_2SV4CLUK7DPAHG7NWFFOFLC6QAPTNYFY.xml
# Datei gespeichert: La_Otra_Alemania\1943-10-01_XWJ3V6R6Z3UA725FUGKBKA3WORJW54IH.xml
# Datei gespeichert: La_Otra_Alemania\1946-01-01_FJ3TTMC37BVBT4NACRQ5TS4YV6PE35MX.xml
# Datei gespeichert: La_Otra_Alemania\1945-09-01_T4BXWFJE6JIKSVUKYR75NWIX7F3NYPYB.xml
# Datei gespeichert: La_Otra_Alemania\1946-01-15_V3NBQXV27SIY6SCZ6AHC2SFB6OOFYL2P.xml
# Datei gespeichert: La_Otra_Alemania\1947-09-01_DPL4RATQOYXYDHBE673VJTXJADOLIL5M.xml
# Datei gespeichert: La_Otra_Alemania\1947-08-01_OBXY2AWLM6JJT4D44MJMKQNG3C46UCYZ.xml
# Datei gespeichert: La_Otra_Alemania\1947-06-15_6RCHCLSPHELELZX2S3CE65BDOADJAESZ.xml
# Datei gespeichert: La_Otra_Alemania\1946-04-15_IIG747FNS2RZB6ULI3O2PHQPA6MYNXQ4.xml
# Datei gespeichert: La_Otra_Alemania\1948-03-01_BYGKGXD3AT4DAXIIZW7HKCT6IVGH5LF3.xml
# Datei gespeichert: La_Otra_Alemania\1947-02-15_ZWQRVQMFEW3UGBM5FLEX5R4MZHZ47KQB.xml
# Datei gespeichert: La_Otra_Alemania\1943-12-15_HXVO7BHOAELLKF52DWCLMQDIYPJ6YQKM.xml
# Datei gespeichert: La_Otra_Alemania\1948-06-15_MPTSKCFOVUJXB2J67LZ4I54HZKRW5XA4.xml
# Datei gespeichert: La_Otra_Alemania\1945-12-01_DGKO5ECCHOWTM4PPMDBE3H5VMM5C6I6E.xml
# Datei gespeichert: La_Otra_Alemania\1945-02-01_AIJ7P5KTYD7HJZHBIODEDJY6XSLUYLRO.xml
# Datei gespeichert: La_Otra_Alemania\1946-08-01_MMJX3P3AFQO2ZJT3DPNTKI2E7TNTM67B.xml
# Datei gespeichert: La_Otra_Alemania\1944-08-01_SJOKX4BFOBZ7IT4YANU2XOGG3OKU5RVF.xml
# Datei gespeichert: La_Otra_Alemania\1947-09-15_4V3XF7ALYN4QWF6YIMYTN2PJJOZSZS4E.xml
# Datei gespeichert: La_Otra_Alemania\1947-05-01_ZGBM5CKKHGTT64O6XPK5OAMFHEMQHZDP.xml
# Datei gespeichert: La_Otra_Alemania\1947-03-15_DIO2AY54GFQQ7XTP3GO4KSH4EGBULBOD.xml
# Datei gespeichert: La_Otra_Alemania\1948-11-01_3D6BREK63MDQNKZUGBIZNZKMCRII3MAI.xml
# Datei gespeichert: La_Otra_Alemania\1946-11-01_YX2N4YR45ZGRN4TKLNGSGC3FUQJVRCBA.xml
# Datei gespeichert: La_Otra_Alemania\1946-03-15_EXLFBX7ZM7SVOXI2YJLQ7L5UWN573VQ7.xml
# Datei gespeichert: La_Otra_Alemania\1946-06-01_Z76XXSNMWRS5ZRPCOTYTA5E5UKO6FPVP.xml
# Datei gespeichert: La_Otra_Alemania\1948-09-01_I5U6VCZUGRNQLPZYJ3SXYDI3NJJ6SXI6.xml
# Datei gespeichert: La_Otra_Alemania\1946-09-01_MZS7UIAI6UFSUXBOBTWE2VTLKNVY5QCL.xml
# Datei gespeichert: La_Otra_Alemania\1946-02-15_NCEUH4UZ6KSDEOZAWMISNMOHE7QPEVEY.xml
# Datei gespeichert: La_Otra_Alemania\1945-06-01_UC4JQ6DOF5RUPFPRY24YUXKMXNR4EOX4.xml
# Datei gespeichert: La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU.xml
# Datei gespeichert: La_Otra_Alemania\1947-02-01_2BWF5FGDWMD463EOUQ5PVZCGV36WVAEB.xml
# Datei gespeichert: La_Otra_Alemania\1948-08-01_XLIYJGKPKCV6OIZVJ2E5Y6XFZUUFCXDR.xml
# Datei gespeichert: La_Otra_Alemania\1945-07-01_QSO254EY4S35PFBT6T25UZXOIXGZOUZB.xml
# Datei gespeichert: La_Otra_Alemania\1945-03-01_PBIKLXIOC4YIVKWLH5YGQ4V5LVX7TCV5.xml
# Datei gespeichert: La_Otra_Alemania\1947-06-01_2IRB7LPRGZ4IOBIELXAFG5XRIGA4IBIO.xml
# Datei gespeichert: La_Otra_Alemania\1945-09-15_MJLH3WN4QS47AML3NKLTLG6WJVVPQRAF.xml
# Datei gespeichert: La_Otra_Alemania\1946-06-15_63R5DPUJ5S3CUL5DYCUPMLJNKXHSN7SJ.xml
# Datei gespeichert: La_Otra_Alemania\1946-10-01_SJKG4ZFKPBYZK4UZRBYPMAOEQZ555C4P.xml
# Datei gespeichert: La_Otra_Alemania\1946-10-15_IIAJP5EE4U6OOLBPXAVIA4LGNDU44EFJ.xml
# Datei gespeichert: La_Otra_Alemania\1946-07-01_XFL3GU2ZVC4YMZB2LUIPGODKASCB7X3K.xml
# Datei gespeichert: La_Otra_Alemania\1948-02-15_5ZWIBB26KKXVY274IF2PGBXFGPLCSRAT.xml
# Datei gespeichert: La_Otra_Alemania\1948-04-01_ZN5JESVZENF7HFSMDKTD4SJUGVEDR7QO.xml
# Datei gespeichert: La_Otra_Alemania\1944-07-01_3FCNJLRNPHJFOQUZIUNLPJAJRUH2LQ4L.xml
# Datei gespeichert: La_Otra_Alemania\1947-01-01_5CUTOS3UUGHFBQ2YDTXVFNH3Z6IRQO56.xml
# Datei gespeichert: La_Otra_Alemania\1948-06-01_VYCG6AOEGLHHO5O5X2DSRKPCYYE2X627.xml
# Datei gespeichert: La_Otra_Alemania\1945-10-15_HQN2MLIFQL23DVNQOXE7PXFZYC4G5ZMS.xml
# Datei gespeichert: La_Otra_Alemania\1948-10-01_L2V3WIPUNGYL3JL2EEUZITVITQHTXGO7.xml
# Datei gespeichert: La_Otra_Alemania\1943-03-20_ZJ2I36A2L72ZSMHQSUELBO7TVNZCAM34.xml
# Datei gespeichert: La_Otra_Alemania\1947-05-15_PJ7NLJQQKFSWXXP4VWG3NSOAAZK4VZTV.xml
# Datei gespeichert: La_Otra_Alemania\1946-05-15_DQY2ALVOTLAZ2HDLQAGLMSSSVAWZQAOK.xml
# Datei gespeichert: La_Otra_Alemania\1946-05-01_S2QTXBSAHGCZSMYSJWDMI5UWTZPEDU4W.xml
# Datei gespeichert: La_Otra_Alemania\1944-09-01_4F6PC344QMSU4JYBTVIY3VIUXKRGOBMI.xml
# Datei gespeichert: La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4.xml
# Datei gespeichert: La_Otra_Alemania\1948-03-15_NAZHQUKDTTOW4WDH7FYUEEWIAKPUBDFN.xml
# Datei gespeichert: La_Otra_Alemania\1946-02-01_YTWERRMATCUM43IVECX5U2MDP6HS3NOF.xml
# Datei gespeichert: La_Otra_Alemania\1948-07-01_DO5LN2GHGH6OXIXRVAYSYKOKG64A5Z64.xml
# Datei gespeichert: La_Otra_Alemania\1947-01-15_2E6XHDPDEXN3ZFO3IL2SXGH3TBEMC2GC.xml
# Datei gespeichert: La_Otra_Alemania\1943-05-15_FKSMSFXJDK5WZDNKOVKGVNVDMDDRSUC5.xml
# Datei gespeichert: La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4.xml
# Datei gespeichert: La_Otra_Alemania\1942-08-01_MXURZUI2TNZ76K4YXTTPF5LI4O7JYGAO.xml
# Datei gespeichert: La_Otra_Alemania\1946-12-15_JCD5YAPQOGPMFI2T6RKP4GA3Z7WNN7WQ.xml
# Datei gespeichert: La_Otra_Alemania\1947-07-01_HHJX6JF6XZXGNA22FSHKMDDVP5KATS4J.xml
# Datei gespeichert: La_Otra_Alemania\1945-10-01_SZXP6GEGBOD42J5TKYQ64XNDTUJO2S77.xml
# Datei gespeichert: La_Otra_Alemania\1943-12-15_CAMRPRGLRHFMUJFGTVKX4RW5KJTRR5LT.xml
# Datei gespeichert: La_Otra_Alemania\1947-10-01_DGJVAWT6K23ZQ5TVOSAKADSDJSSYQV3V.xml
# Datei gespeichert: La_Otra_Alemania\1947-11-15_BA5FYSSHUMOEXBAZHFQMT4LI3V4VBQBA.xml
# Fertig!

# %% [markdown]
# ## Download der Bild- und Volltextdaten
#
# Die heruntergeladenen METS/MODS-Daten enthalten Verlinkungen zu allen Bild- und Volltextdaten. Eine stark verkürzte und schematische Darstellung der METS/MODS-Struktur, die insbesondere die Positionen von `mets:fileSec` und `mets:fileGrp` zeigt, sieht wie folgt aus. Hier muss man beachten, dass eine `mets:fileGrp` immer eine zusammengehörige Gruppe von Dateien bildet. Es sind `DEFAULT` (Link zu Bilddateien beim Datenpartner der Deutschen Digitalen Bibliothek) und `DDB_FULLTEXT` (Link zu den Volltextdaten bei der Deutschen Digitalen Bibliothek) interessant.
#
# ```XML
# <mets:mets xmlns:mets="http://www.loc.gov/METS/" xmlns:mods="http://www.loc.gov/mods/v3">
#
#   <!-- Header -->
#   <mets:metsHdr CREATEDATE="2024-07-30T12:00:00">
#     <!-- Agent Information -->
#   </mets:metsHdr>
#
#   <!-- Descriptive Metadata -->
#   <mets:dmdSec ID="dmd001">
#     <mets:mdWrap MDTYPE="MODS">
#       <mets:xmlData>
#         <mods:mods>
#           <!-- MODS Metadata -->
#         </mods:mods>
#       </mets:xmlData>
#     </mets:mdWrap>
#   </mets:dmdSec>
#
#   <!-- File Section -->
#   <mets:fileSec>
#     <mets:fileGrp USE="DEFAULT">
#       <mets:file ID="file0001" MIMETYPE="image/jpeg">
#         <mets:FLocat LOCTYPE="URL" xlink:href="http://example.com/image1.jpg"/>
#       </mets:file>
#     </mets:fileGrp>
#     <mets:fileGrp USE="DDB_FULLTEXT">
#       <mets:file ID="file0002" MIMETYPE="text/xml">
#         <mets:FLocat LOCTYPE="URL" xlink:href="http://example.com/fulltext1.xml"/>
#       </mets:file>
#     </mets:fileGrp>
#   </mets:fileSec>
#
#   <!-- Structural Map -->
#   <mets:structMap TYPE="logical">
#     <mets:div TYPE="document" DMDID="dmd001">
#       <mets:div TYPE="page" ORDER="1">
#         <mets:fptr FILEID="file0001"/>
#       </mets:div>
#       <mets:div TYPE="page" ORDER="2">
#         <mets:fptr FILEID="file0002"/>
#       </mets:div>
#     </mets:div>
#   </mets:structMap>
#
# </mets:mets>
#
# ```
#
# #### xPath-Querys
#
# Eine Möglichkeit diese Informationen mit einer Abfragesprache für XML-Daten abzufragen ist [xPath](https://de.wikipedia.org/wiki/XPath). Die Abfragen (Querys) sehen wie folgt aus:
#
# - DEFAULT-Bilder: `//mets:mets/mets:fileSec/mets:fileGrp[@USE="DEFAULT"]/mets:file/mets:FLocat/@xlink:href`
# - DDB_FULLTEXT-Volltexte: `//mets:mets/mets:fileSec/mets:fileGrp[@USE="DDB_FULLTEXT"]/mets:file/mets:FLocat/@xlink:href`
#
# ### KI-generierter Programmcode
#
# <div class="alert alert-block alert-info">
# <p><b>Prompt:</b> Erstelle ein möglichst einfaches Python-Skript, das alle METS/MODS-Dateien in dem Verzeichnis <code>La_Otra_Alemania</code> einliest und URLs mittels des XPath-Ausdrucks <code>//mets:mets/mets:fileSec/mets:fileGrp[@USE="DDB_FULLTEXT"]/mets:file/mets:FLocat/@xlink:href</code> extrahiert. Die extrahierten URLs sollen heruntergeladen und in Unterverzeichnissen gespeichert werden. Die Unterverzeichnisse werden nach den Dateinamen der METS/MODS-Dateien benannt. Die heruntergeladenen XML-Dateien sollen mit 1 beginnend durchnummeriert werden.</p>
#
# <p>Das Gleiche soll mit JPEG-Dateien und dem xPath-Ausdruck <code>//mets:mets/mets:fileSec/mets:fileGrp[@USE="DEFAULT"]/mets:file/mets:FLocat/@xlink:href</code> gemacht werden.</p>
# </div>

# %%
# Python-Bibliothek lxml installieren
# %pip install -q lxml
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from lxml import etree

# Definiere die Namensräume
NAMESPACES = {
    'mets': 'http://www.loc.gov/METS/',
    'xlink': 'http://www.w3.org/1999/xlink'
}

# Verzeichnisse definieren
xml_directory = 'La_Otra_Alemania'
download_directory = 'La_Otra_Alemania'

# Erstelle das Download-Verzeichnis, falls es nicht existiert
if not os.path.exists(download_directory):
    os.makedirs(download_directory)

# Funktion, um URLs aus einer XML-Datei zu extrahieren und herunterzuladen
def download_files_from_xml(xml_file_path, xpath_expr, subfolder, extension):
    # Lade die XML-Datei ein
    with open(xml_file_path, 'rb') as xml_file:
        tree = etree.parse(xml_file)

    # Extrahiere die URLs mit dem gegebenen XPath-Ausdruck
    urls = tree.xpath(xpath_expr, namespaces=NAMESPACES)

    # Erstelle das Unterverzeichnis, benannt nach der XML-Datei
    xml_file_name = os.path.splitext(os.path.basename(xml_file_path))[0]
    destination_dir = os.path.join(download_directory, xml_file_name, subfolder)
    os.makedirs(destination_dir, exist_ok=True)

    # Lade jede URL herunter und speichere die Datei
    for i, url in enumerate(urls, start=1):
        try:
            response = requests.get(url)
            response.raise_for_status()  # Überprüfe auf HTTP-Fehler
            file_path = os.path.join(destination_dir, f'{i}.{extension}')
            with open(file_path, 'wb') as output_file:
                output_file.write(response.content)
            print(f'Downloaded {url} to {file_path}')
        except requests.RequestException as e:
            print(f'Failed to download {url}: {e}')

# Durchlaufe alle XML-Dateien im Verzeichnis
for xml_file in os.listdir(xml_directory):
    if xml_file.endswith('.xml'):
        xml_file_path = os.path.join(xml_directory, xml_file)
        # Lade und speichere Dateien mit dem ersten XPath-Ausdruck
        download_files_from_xml(xml_file_path, '//mets:mets/mets:fileSec/mets:fileGrp[@USE="DEFAULT"]/mets:file/mets:FLocat/@xlink:href', 'DEFAULT', 'jpeg')
        # Lade und speichere Dateien mit dem zweiten XPath-Ausdruck
        download_files_from_xml(xml_file_path, '//mets:mets/mets:fileSec/mets:fileGrp[@USE="DDB_FULLTEXT"]/mets:file/mets:FLocat/@xlink:href', 'DDB_FULLTEXT', 'xml')
# Out:
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/1/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\1.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/2/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\2.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/3/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\3.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/4/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\4.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/5/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\5.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/6/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\6.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/7/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\7.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/8/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\8.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/9/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\9.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/10/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\10.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/11/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\11.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/12/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\12.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/13/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\13.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/14/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\14.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/15/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\15.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/16/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\16.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/17/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\17.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/18/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\18.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/19/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\19.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/20/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\20.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/21/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\21.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/22/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\22.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/23/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\23.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/24/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\24.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/25/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\25.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/26/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\26.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552451/img/page/27/p.jpg?reduce=3 to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DEFAULT\27.jpeg
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/2273590c-4736-4d73-90c9-87b7568a9243.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\1.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/49fa21a6-30ea-41cd-9a63-eeb3c2ddb2f7.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\2.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/70c86f51-c555-4abc-8092-46ec8bec193e.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\3.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/a3449ae4-1a50-4970-8450-d2bb90a29b53.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\4.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/323a531f-5eb3-4a0d-a062-5078f11635a7.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\5.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/32149bc5-8933-42b9-bbc2-cec939051c4d.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\6.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/6ff254fc-cf48-46f3-a781-05f2d3456d5a.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\7.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/8b89a238-bdd1-4d83-add9-2f1a6d2edcc1.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\8.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/f4cc39de-fb0b-4f6d-a93b-22bbcf9a37fb.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\9.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/7d3a9be7-eaba-43cf-b783-70f50eaab09a.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\10.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/d3c86177-0de3-464b-9fb4-b77f0d34cdfa.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\11.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/4b48ff5f-bbef-4b3c-837c-dba11459f51a.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\12.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/4420414c-2b6c-42ab-8027-c84a9afa3011.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\13.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/c58ac7ab-d885-4d50-baf0-b9d411aa49ce.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\14.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/d38debcc-2768-4244-a342-7351a23f77d0.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\15.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/1bdb5f19-14eb-4b83-9a44-e27843712b2e.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\16.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/535269d8-9744-4d42-ba59-7bf550fdd472.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\17.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/21161aa4-694c-4630-bc91-de1bc680d53e.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\18.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/3d8b27bf-4629-4605-adfa-a44e398af4e6.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\19.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/ada997c0-56f5-4911-ad4c-7b8a3658a475.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\20.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/0d9e19a4-473b-4141-bab1-b2dceb488747.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\21.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/d7456cc6-8359-40f0-8919-bc400bb5b156.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\22.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/731c7871-ea1b-4544-a4af-4184f04c843b.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\23.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/33f757f2-e2fd-449c-9a01-bca9f2a521d2.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\24.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/6c455a18-146a-4820-8165-bfe6148fea50.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\25.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/33ede57a-caa8-44fa-9af2-432f7f465e24.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\26.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/45da979f-50d6-4290-b0f8-f79b8882860d.xml to La_Otra_Alemania\1942-01-01_BWSVNEKFTM7SPW4SQAWQQNGIHHTRFDS4\DDB_FULLTEXT\27.xml
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/1/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\1.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/2/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\2.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/3/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\3.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/4/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\4.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/5/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\5.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/6/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\6.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/7/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\7.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/8/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\8.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/9/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\9.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/10/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\10.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/11/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\11.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/12/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\12.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/13/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\13.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/14/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\14.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/15/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\15.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/16/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\16.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/17/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\17.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/18/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\18.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/19/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\19.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/20/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\20.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655246X/img/page/21/p.jpg?reduce=3 to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DEFAULT\21.jpeg
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/71551b31-93b1-4f6a-88ad-3c0ea3eaba74.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\1.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/b5bef86b-40de-4409-b28c-87527bb625f5.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\2.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/c79611bc-38e9-41c9-b9b8-4d837dd72688.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\3.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/5b9601c2-a6c7-4045-bcce-9802e6137ece.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\4.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/54234b74-e467-428d-aedd-a23a4a5a0df2.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\5.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/10e3151b-1975-4e33-9568-c6df66b11389.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\6.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/703ddd36-d46e-4ee4-9ebd-f217fbfd9b2a.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\7.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/d68080de-87a3-42b3-bfde-a338531d0d89.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\8.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/94b09d2e-1e2b-46f0-bb9d-8fccf789d450.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\9.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/1f7c3f3b-41ce-4f98-a9f9-2ddfca5a3b79.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\10.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/a3b5203d-c70c-43b5-b0d8-7d7b2bf5a95f.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\11.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/7145bf8e-d5e2-40d0-9987-1c2d17987837.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\12.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/75a7a088-7899-466a-9841-e35f55223a49.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\13.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/5e4d9b5a-d5b4-480d-9b33-a5ca3532067b.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\14.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/e9e9e68b-6ef7-4e60-b2fb-e2008b8dccb6.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\15.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/770016c3-7c16-4274-bbdf-cb2bf1e91633.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\16.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/03380084-af89-406f-b6d7-8fe0f8e2905d.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\17.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/f88b4658-f6ac-4ff4-aaaf-003058145489.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\18.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/f6bc9d2c-bdbd-433c-b504-94b334e27de5.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\19.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/f7e5cc06-0efc-4481-b1f2-b6cbb421e411.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\20.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/bc90250d-071d-4f33-a98c-3cb5fb8d6425.xml to La_Otra_Alemania\1942-02-01_2PLM4WNWNAPWDQPI6PBTW2CQ2OH5W3DU\DDB_FULLTEXT\21.xml
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/1/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\1.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/2/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\2.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/3/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\3.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/4/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\4.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/5/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\5.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/6/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\6.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/7/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\7.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/8/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\8.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/9/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\9.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/10/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\10.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/11/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\11.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/12/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\12.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/13/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\13.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/14/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\14.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/15/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\15.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/16/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\16.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/17/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\17.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/18/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\18.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/19/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\19.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/20/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\20.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552478/img/page/21/p.jpg?reduce=3 to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DEFAULT\21.jpeg
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/c744ae10-a50e-4b60-8722-1d2ff4798bd7.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\1.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/5f03ee7a-ef59-4b79-8f88-4dd6231e195b.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\2.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/578e208d-df3e-4fea-866f-1e5319435af1.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\3.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/9a969c6f-b99a-432a-8cff-833e799b8bb0.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\4.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/c8187c7c-6fef-4bf9-994e-0a04ba44bb10.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\5.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/c3b93a2b-2b16-4200-ac3a-927b3b74e713.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\6.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/cac4c58b-3411-456a-85f2-4bd14246771f.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\7.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/e69550b1-fda1-405c-ac02-6f08f9a0fb47.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\8.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/2e18e8af-fe1b-4ef2-800b-476bcb1e52b1.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\9.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/9b16b446-dbd2-42d1-948d-a93320fe1038.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\10.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/fcedfebc-6f98-40e2-a27f-44b431cb2a86.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\11.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/4254133d-716c-4f95-bad9-d866dd71e8b5.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\12.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/b31e6046-91f4-4a94-9882-57bdd341bdab.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\13.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/2531277d-4eb9-4261-87c5-e717eeeca0dd.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\14.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/1599f529-293e-4e4f-b805-7a882123f34e.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\15.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/78c4fc5a-d941-47f5-9819-06d893e336fd.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\16.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/bd3c176d-bd4a-4f79-9f07-c3105045c2f9.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\17.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/117a231d-2112-4833-be5e-ddd8e056c8f2.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\18.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/e7c636ac-78ca-48d5-a042-a1a53a89d0e7.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\19.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/b43236a8-7510-4b97-9afa-0378ae688947.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\20.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/7bdd0f90-9082-4231-872e-80132bbd742f.xml to La_Otra_Alemania\1942-03-01_RCI3TRECLGLJQ6NP4SHYQ4PONQ7SVOT5\DDB_FULLTEXT\21.xml
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/1/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\1.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/2/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\2.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/3/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\3.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/4/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\4.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/5/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\5.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/6/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\6.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/7/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\7.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/8/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\8.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/9/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\9.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/10/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\10.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/11/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\11.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/12/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\12.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/13/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\13.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/14/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\14.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/15/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\15.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/16/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\16.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/17/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\17.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/18/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\18.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/19/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\19.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/20/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\20.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552486/img/page/21/p.jpg?reduce=3 to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DEFAULT\21.jpeg
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/66ea95da-b876-4b5f-bdd5-347b824afe42.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\1.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/3f580b39-9cd3-4ab0-8a03-f0af7c10b327.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\2.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/3321e7c4-54a7-4248-bb69-2abcaf679b58.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\3.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/1885980f-fe2f-41d0-bd1e-f4b0ba129b71.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\4.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/518677b8-840a-488a-8bc3-1a23ea62eb6d.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\5.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/fa0e91f4-b03f-4dc3-b05a-e5d3b015574f.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\6.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/32219244-28f1-46b6-9736-ba6c322eab0c.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\7.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/ba3c41ae-1c08-41c9-9b01-53a3a59ea59d.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\8.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/cb4ec863-5fd5-44b2-9404-ab27e0bc4948.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\9.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/6918fb49-b04e-4bc9-85e9-dfb8872942f8.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\10.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/a4ea916e-c125-459f-8111-d7af3b6bcbf4.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\11.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/628d5bf4-978d-4074-8b29-986ba2a5c83c.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\12.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/b5c7e88b-e81b-4f36-a35f-fba70f5c2a95.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\13.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/8dbb2855-9497-4a08-90a7-182f0269bcd3.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\14.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/91581f39-f94f-4819-95f6-589084bfb38e.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\15.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/2a4dc727-0b7e-4c65-a45d-56d56ef47794.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\16.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/e7c24990-9218-4918-9fec-be3a7780f861.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\17.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/ba10d426-e798-418e-bace-6fd819a1fd6c.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\18.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/f04871f7-c76b-4e88-a598-ea30f6666f95.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\19.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/ba211e3c-87fd-477d-9523-45e4f30272eb.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\20.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/6e4757b1-df1f-4b35-b231-7e49e8e24110.xml to La_Otra_Alemania\1942-04-01_55B56D7HO7MQVEBKOZW4XNFJH2NNNXWC\DDB_FULLTEXT\21.xml
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/1/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\1.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/2/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\2.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/3/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\3.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/4/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\4.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/5/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\5.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/6/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\6.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/7/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\7.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/8/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\8.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/9/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\9.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/10/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\10.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/11/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\11.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/12/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\12.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/13/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\13.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/14/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\14.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/15/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\15.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/16/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\16.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/17/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\17.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/18/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\18.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/19/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\19.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/20/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\20.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552494/img/page/21/p.jpg?reduce=3 to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DEFAULT\21.jpeg
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/ea0692ef-101f-48bb-b44f-2ca79427fe6e.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\1.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/ac5e55f0-7d34-4cf3-9c32-99907c16381e.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\2.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/3a202978-7508-45f7-be34-c943c96d5717.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\3.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/28658c06-09cc-41ab-b627-cb9b26c51c97.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\4.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/b1f08205-0325-4ba3-8597-f21c8723da31.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\5.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/2f7dee2e-0009-4bc3-a597-332adab038f7.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\6.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/a336960a-5a2c-44d6-a16a-6bf88aaad723.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\7.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/ed3e29e3-446f-456f-85a7-29327c6d66aa.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\8.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/cb3b5e01-e599-4721-96b2-75ac7aac7f21.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\9.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/cfc447ab-ae61-4ba4-9812-68fe4df67abe.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\10.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/411a2cc3-cc4d-4cf5-bffb-a153c6ca1017.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\11.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/789c684e-db1e-472c-bbb0-462305d7845d.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\12.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/44c40561-dbfa-488c-8e76-1f7d6a6a2fe6.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\13.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/a0289808-5314-4fa9-9756-0edb3928541b.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\14.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/2ff012b0-bac7-454e-b605-eb3ddc98b80c.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\15.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/e5537120-35e2-4673-97c4-0ce3fe5ab446.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\16.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/6fb5629f-96ad-4e34-afd8-383e78cbf1f9.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\17.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/a85cab39-246c-4487-8107-4a48d613ca1a.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\18.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/3e072826-f564-4395-bfb9-c90ee80d2203.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\19.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/9aaf47c2-27f9-4f52-b6c3-edb5ea16c3ac.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\20.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/dce6bf1b-bd9f-4bbe-8e38-1f98ce8f0462.xml to La_Otra_Alemania\1942-05-01_TJ6BV7NK6JA62D6NDUXQHCYJCN3YNHLO\DDB_FULLTEXT\21.xml
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/1/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\1.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/2/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\2.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/3/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\3.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/4/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\4.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/5/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\5.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/6/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\6.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/7/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\7.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/8/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\8.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/9/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\9.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/10/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\10.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/11/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\11.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/12/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\12.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/13/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\13.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/14/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\14.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/15/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\15.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/16/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\16.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/17/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\17.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/18/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\18.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/19/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\19.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/20/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\20.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552508/img/page/21/p.jpg?reduce=3 to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DEFAULT\21.jpeg
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/c1b2745b-b8ac-4b0f-a738-7481ebf1f3a3.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\1.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/b2e85ef7-4bde-4598-ab8e-d1afebecd377.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\2.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/6e4c4b43-c3d6-4276-81dc-478dcf605897.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\3.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/88219531-930b-4d89-b4c5-d2aa49a16899.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\4.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/9aa1ae49-9f1f-4276-9333-e2a2096b88c6.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\5.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/7d8adf27-3dab-4b08-9da9-48b031288b9e.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\6.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/57121bc9-358f-4c2f-9b63-810915fb62d3.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\7.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/7f155904-b435-4512-acac-57c35f3d7e21.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\8.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/38805b32-19a2-4358-9352-9a741c1dc4d2.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\9.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/13736767-6281-4b1a-a7f9-2f9d62f3fa55.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\10.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/fe29720a-9bbe-4b5c-b3ae-65abaafc119b.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\11.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/8d1a0071-f42f-4c74-a6ae-5412a931dce3.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\12.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/b16bc011-a5f0-4f0a-9f61-2532d698e1f6.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\13.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/6e09ae45-82bc-4d2b-939f-daff13efd9a2.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\14.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/0233218a-6ae3-4c10-bece-505a2e5c611d.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\15.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/4bca792c-e82a-4e40-963f-22cee4a4ac98.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\16.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/928de823-f4ef-4982-b335-7c9d2907831c.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\17.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/08781029-736b-4c83-961d-cdc782cf1896.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\18.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/74a47f85-99df-4c0e-b122-e65597d423d6.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\19.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/7da88d36-2b01-4a98-a3b4-1cfc22da4187.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\20.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/500d7686-b94f-425e-843a-9412ae75e60f.xml to La_Otra_Alemania\1942-06-01_PEEJYOSFJYOQEICPQZA6MM2R7ZGGEXZT\DDB_FULLTEXT\21.xml
# Downloaded https://portal.dnb.de/bookviewer/view/1026552516/img/page/1/p.jpg?reduce=3 to La_Otra_Alemania\1942-07-01_LJ5BPAX4ZT4KQ3IUDPOSRFBJ2FKVSVNP\DEFAULT\1.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552516/img/page/2/p.jpg?reduce=3 to La_Otra_Alemania\1942-07-01_LJ5BPAX4ZT4KQ3IUDPOSRFBJ2FKVSVNP\DEFAULT\2.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552516/img/page/3/p.jpg?reduce=3 to La_Otra_Alemania\1942-07-01_LJ5BPAX4ZT4KQ3IUDPOSRFBJ2FKVSVNP\DEFAULT\3.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552516/img/page/4/p.jpg?reduce=3 to La_Otra_Alemania\1942-07-01_LJ5BPAX4ZT4KQ3IUDPOSRFBJ2FKVSVNP\DEFAULT\4.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552516/img/page/5/p.jpg?reduce=3 to La_Otra_Alemania\1942-07-01_LJ5BPAX4ZT4KQ3IUDPOSRFBJ2FKVSVNP\DEFAULT\5.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552516/img/page/6/p.jpg?reduce=3 to La_Otra_Alemania\1942-07-01_LJ5BPAX4ZT4KQ3IUDPOSRFBJ2FKVSVNP\DEFAULT\6.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552516/img/page/7/p.jpg?reduce=3 to La_Otra_Alemania\1942-07-01_LJ5BPAX4ZT4KQ3IUDPOSRFBJ2FKVSVNP\DEFAULT\7.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552516/img/page/8/p.jpg?reduce=3 to La_Otra_Alemania\1942-07-01_LJ5BPAX4ZT4KQ3IUDPOSRFBJ2FKVSVNP\DEFAULT\8.jpeg
# ...
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/13/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\13.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/14/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\14.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/15/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\15.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/16/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\16.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/17/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\17.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/18/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\18.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/19/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\19.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/20/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\20.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/21/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\21.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/22/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\22.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/23/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\23.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/24/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\24.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/25/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\25.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/26/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\26.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/102655263X/img/page/27/p.jpg?reduce=3 to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DEFAULT\27.jpeg
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/b4599df0-77a1-45cf-87dc-23da9bf758e1.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\1.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/061e38fd-7144-41a2-8152-22abcf591c5d.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\2.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/aa959d43-d8c5-4efa-9f43-f915e3e27fc9.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\3.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/6cde527f-c9a1-482c-b2d6-230f0e7dc19f.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\4.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/c7b0014b-37d9-4841-b9a3-2d9354d2177d.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\5.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/e42199b0-8b82-4267-9d1f-11ecff2e5859.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\6.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/c9caf02a-7dba-4f11-86d0-451a1730e916.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\7.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/80d2cbc3-c9f5-4d25-b14f-e4c4f6a5630f.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\8.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/538522e5-9e42-4e41-bd36-0d8442db1b7f.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\9.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/208e64e2-e56a-40ca-9b7f-82f0f7ec386b.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\10.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/a67a310f-6cd6-4bfd-a520-0407ea456560.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\11.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/1c263bd1-6bfe-43fb-bf40-88c8615fc4a5.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\12.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/a99e1dce-d109-474b-9a57-3e2b3ba50615.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\13.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/127e5f1e-3c48-42ba-8c99-47c687523663.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\14.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/ced8fd4b-044f-4faf-86a4-8c3244b5e8c1.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\15.xml
# Failed to download https://api.deutsche-digitale-bibliothek.de/binary/826127b7-9f38-47c1-a810-b5e35797ea45.xml: 500 Server Error:  for url: https://api.deutsche-digitale-bibliothek.de/binary/826127b7-9f38-47c1-a810-b5e35797ea45.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/0514721c-ac04-4a24-8240-a38efbf2b938.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\17.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/32c97a80-12dc-40b2-b2e0-a9ab86f58769.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\18.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/5d42a87c-5531-444f-a572-fb25a9586ae8.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\19.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/ed210dad-5d5a-46af-bf78-7aaaa27d59a8.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\20.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/9e34f49d-da78-41ff-811d-30507e1fdb8c.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\21.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/8a9d8d1a-d4ae-4c82-be7f-38f308e4cdaf.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\22.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/6d9f9b12-9618-4a03-945b-be5d164d28cb.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\23.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/791911e9-9b6f-4fad-a0a8-49d66f6beec8.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\24.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/ab167eb6-9056-40ff-8172-27519290d742.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\25.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/c8dfac4c-1490-4b33-9414-0485be1e335e.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\26.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/b1360717-bd65-4a65-a404-8d9cc5a9246c.xml to La_Otra_Alemania\1943-04-15_LGNZTM5BKS533MUV5YRBCGZS37MI5WU4\DDB_FULLTEXT\27.xml
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/1/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\1.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/2/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\2.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/3/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\3.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/4/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\4.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/5/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\5.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/6/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\6.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/7/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\7.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/8/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\8.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/9/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\9.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/10/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\10.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/11/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\11.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/12/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\12.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/13/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\13.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/14/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\14.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/15/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\15.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/16/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\16.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/17/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\17.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/18/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\18.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/19/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\19.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/20/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\20.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/21/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\21.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/22/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\22.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/23/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\23.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/24/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\24.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/25/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\25.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/26/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\26.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/27/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\27.jpeg
# Downloaded https://portal.dnb.de/bookviewer/view/1026552648/img/page/28/p.jpg?reduce=3 to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DEFAULT\28.jpeg
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/7601a3d2-dede-4009-bae8-804b79a532c1.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\1.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/86cf874b-ce4f-451b-9d01-f8eed59f378d.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\2.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/ffee14ba-c6d6-4367-ac29-d999042551a9.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\3.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/3394f37b-ced7-4135-95d8-1b3b87d3969d.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\4.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/3d7f0dd7-8942-4054-a94a-f636992fd1b6.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\5.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/e37a4f94-e0f6-4ba1-b2bf-31575d4ca614.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\6.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/e930e0bd-b31c-4fca-9239-bee66fc0a6e2.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\7.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/65dbbf18-71de-4c2f-ae46-2c9af93ae9c0.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\8.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/b148dddf-dc42-441b-accb-32c224f034a7.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\9.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/cca1e384-dda0-4cb6-91e5-eec24f3ed562.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\10.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/49886627-7ad0-4d21-adef-6a865d4aa101.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\11.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/eee53bd4-d91b-4be8-b709-e13199b1bf42.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\12.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/9afe7ea4-5f33-49ce-bef1-219bb9736da8.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\13.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/9c12bd33-8183-4845-a64d-0d173fa743f7.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\14.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/9b5670da-6405-4b35-aba6-22f883539a1b.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\15.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/8e7f6597-3032-4451-be71-a01cc31ad02c.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\16.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/9c81d697-5572-434d-86ed-7fe37b7859fd.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\17.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/497cdcff-0a7b-469a-9e26-3b90e9095192.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\18.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/100438de-6a5e-4ed1-b780-81a54e035991.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\19.xml
# Downloaded https://api.deutsche-digitale-bibliothek.de/binary/161168a3-9866-4f0c-8213-00728291fb90.xml to La_Otra_Alemania\1943-05-01_IO2HCKK56WNGRQYV4MU66PE4TS7PKESU\DDB_FULLTEXT\20.xml
