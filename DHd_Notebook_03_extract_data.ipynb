# %%
import requests
import pandas as pd
import lxml.etree as ET
from bs4 import BeautifulSoup as soup
import unicodedata
import tqdm
from time import sleep
import time

# %% [markdown]
# ## Laden der Daten aus Datei:

# %%
# open from file: 
with open("pandemie_titeldaten.xml", "r", encoding="utf-8") as f2:
    result = f2.readlines()

# %% [markdown]
# Parsen des XML aus Datei:

# %%
content = "".join(result)
xml = soup(content, "lxml")
#print(xml)

# %% [markdown]
# Heraussuchen aller Datensätze des Typs "Bibliographic" aus dem XML:

# %%
myquery = xml.find_all('record', {'type':'Bibliographic'})
print(len(myquery))
# Out:
# 11368

# %%
print(myquery[1].prettify())
# Out:
# <record type="Bibliographic" xmlns="http://www.loc.gov/MARC21/slim">
#  <leader>
#   00000nam a2200000uc 4500
#  </leader>
#  <controlfield tag="001">
#   1317002237
#  </controlfield>
#  <controlfield tag="003">
#   DE-101
#  </controlfield>
#  <controlfield tag="005">
#   20240214080110.0
#  </controlfield>
#  <controlfield tag="007">
#   cr||||||||||||
#  </controlfield>
#  <controlfield tag="008">
#   240124s2024    gw |||||om||| 00||||ger
#  </controlfield>
#  <datafield ind1=" " ind2=" " tag="015">
#   <subfield code="a">
#    24,O02
#   </subfield>
#   <subfield code="2">
#    dnb
#   </subfield>
#  </datafield>
#  <datafield ind1="7" ind2=" " tag="016">
#   <subfield code="2">
#    DE-101
#   </subfield>
#   <subfield code="a">
#    1317002237
#   </subfield>
#  </datafield>
#  <datafield ind1="7" ind2=" " tag="024">
#   <subfield code="2">
#    urn
#   </subfield>
#   <subfield code="a">
#    urn:nbn:de:bsz:14-qucosa2-890970
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="035">
#   <subfield code="a">
#    (DE-599)DNB1317002237
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="035">
#   <subfield code="a">
#    (OCoLC)1420179613
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="040">
#   <subfield code="a">
#    1140
#   </subfield>
#   <subfield code="b">
#    ger
#   </subfield>
#   <subfield code="c">
#    DE-101
#   </subfield>
#   <subfield code="d">
#    9999
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="041">
#   <subfield code="8">
#    1\p
#   </subfield>
#   <subfield code="a">
#    ger
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="044">
#   <subfield code="c">
#    XA-DE-SN
#   </subfield>
#  </datafield>
#  <datafield ind1="7" ind2="4" tag="082">
#   <subfield code="8">
#    7\p
#   </subfield>
#   <subfield code="a">
#    616.2
#   </subfield>
#   <subfield code="q">
#    DE-101
#   </subfield>
#   <subfield code="2">
#    23kdnb
#   </subfield>
#  </datafield>
#  <datafield ind1="7" ind2=" " tag="083">
#   <subfield code="8">
#    8\p
#   </subfield>
#   <subfield code="a">
#    610
#   </subfield>
#   <subfield code="q">
#    DE-101
#   </subfield>
#   <subfield code="2">
#    23sdnb
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="084">
#   <subfield code="a">
#    610
#   </subfield>
#   <subfield code="2">
#    ddc
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="084">
#   <subfield code="a">
#    YH 6904
#   </subfield>
#   <subfield code="2">
#    rvk
#   </subfield>
#  </datafield>
#  <datafield ind1="1" ind2=" " tag="100">
#   <subfield code="8">
#    2\p
#   </subfield>
#   <subfield code="0">
#    (DE-588)1319042198
#   </subfield>
#   <subfield code="0">
#    https://d-nb.info/gnd/1319042198
#   </subfield>
#   <subfield code="0">
#    (DE-101)1319042198
#   </subfield>
#   <subfield code="a">
#    Junghans, Julia
#   </subfield>
#   <subfield code="d">
#    1997-
#   </subfield>
#   <subfield code="e">
#    Verfasser
#   </subfield>
#   <subfield code="4">
#    aut
#   </subfield>
#   <subfield code="2">
#    gnd
#   </subfield>
#  </datafield>
#  <datafield ind1="1" ind2="0" tag="245">
#   <subfield code="a">
#    Ängste der Allgemeinbevölkerung in Zeiten der COVID-19-Pandemie und deren gesundheitliche Bewältigung
#   </subfield>
#   <subfield code="c">
#    Julia Junghans ; Gutachter: Hendrik Berth, Yve Stöbel-Richter
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2="1" tag="264">
#   <subfield code="a">
#    Dresden
#   </subfield>
#   <subfield code="b">
#    Technische Universität Dresden
#   </subfield>
#   <subfield code="c">
#    2024
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="300">
#   <subfield code="a">
#    Online-Ressource
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="336">
#   <subfield code="a">
#    Text
#   </subfield>
#   <subfield code="b">
#    txt
#   </subfield>
#   <subfield code="2">
#    rdacontent
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="337">
#   <subfield code="a">
#    Computermedien
#   </subfield>
#   <subfield code="b">
#    c
#   </subfield>
#   <subfield code="2">
#    rdamedia
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="338">
#   <subfield code="a">
#    Online-Ressource
#   </subfield>
#   <subfield code="b">
#    cr
#   </subfield>
#   <subfield code="2">
#    rdacarrier
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="502">
#   <subfield code="b">
#    Dissertation
#   </subfield>
#   <subfield code="c">
#    Dresden, Technische Universität Dresden
#   </subfield>
#   <subfield code="d">
#    2023
#   </subfield>
#  </datafield>
#  <datafield ind1="1" ind2=" " tag="583">
#   <subfield code="a">
#    Archivierung/Langzeitarchivierung gewährleistet
#   </subfield>
#   <subfield code="5">
#    DE-101
#   </subfield>
#   <subfield code="2">
#    pdager
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2="7" tag="650">
#   <subfield code="8">
#    5\p
#   </subfield>
#   <subfield code="0">
#    (DE-588)4737034-8
#   </subfield>
#   <subfield code="0">
#    https://d-nb.info/gnd/4737034-8
#   </subfield>
#   <subfield code="0">
#    (DE-101)967941407
#   </subfield>
#   <subfield code="a">
#    Pandemie
#   </subfield>
#   <subfield code="2">
#    gnd
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2="7" tag="650">
#   <subfield code="8">
#    6\p
#   </subfield>
#   <subfield code="0">
#    (DE-588)1206347392
#   </subfield>
#   <subfield code="0">
#    https://d-nb.info/gnd/1206347392
#   </subfield>
#   <subfield code="0">
#    (DE-101)1206347392
#   </subfield>
#   <subfield code="a">
#    COVID-19
#   </subfield>
#   <subfield code="2">
#    gnd
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="653">
#   <subfield code="a">
#    Corona
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="653">
#   <subfield code="a">
#    Covid-19
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="653">
#   <subfield code="a">
#    Befinden
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="653">
#   <subfield code="a">
#    Angst
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="653">
#   <subfield code="a">
#    Corona
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="653">
#   <subfield code="a">
#    Covid-19
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="653">
#   <subfield code="a">
#    well-being
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="653">
#   <subfield code="a">
#    anxiety
#   </subfield>
#  </datafield>
#  <datafield ind1="1" ind2=" " tag="700">
#   <subfield code="8">
#    3\p
#   </subfield>
#   <subfield code="0">
#    (DE-588)12882980X
#   </subfield>
#   <subfield code="0">
#    https://d-nb.info/gnd/12882980X
#   </subfield>
#   <subfield code="0">
#    (DE-101)12882980X
#   </subfield>
#   <subfield code="a">
#    Berth, Hendrik
#   </subfield>
#   <subfield code="d">
#    1970-
#   </subfield>
#   <subfield code="e">
#    Gutachter
#   </subfield>
#   <subfield code="4">
#    oth
#   </subfield>
#   <subfield code="2">
#    gnd
#   </subfield>
#  </datafield>
#  <datafield ind1="1" ind2=" " tag="700">
#   <subfield code="8">
#    4\p
#   </subfield>
#   <subfield code="0">
#    (DE-588)122726839
#   </subfield>
#   <subfield code="0">
#    https://d-nb.info/gnd/122726839
#   </subfield>
#   <subfield code="0">
#    (DE-101)122726839
#   </subfield>
#   <subfield code="a">
#    Stöbel-Richter, Yve
#   </subfield>
#   <subfield code="d">
#    1968-
#   </subfield>
#   <subfield code="e">
#    Gutachter
#   </subfield>
#   <subfield code="4">
#    oth
#   </subfield>
#   <subfield code="2">
#    gnd
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="850">
#   <subfield code="a">
#    DE-101a
#   </subfield>
#   <subfield code="a">
#    DE-101b
#   </subfield>
#  </datafield>
#  <datafield ind1="4" ind2="0" tag="856">
#   <subfield code="u">
#    https://nbn-resolving.org/urn:nbn:de:bsz:14-qucosa2-890970
#   </subfield>
#   <subfield code="x">
#    Resolving-System
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2="0" tag="856">
#   <subfield code="u">
#    https://d-nb.info/1317002237/34
#   </subfield>
#   <subfield code="x">
#    Langzeitarchivierung Nationalbibliothek
#   </subfield>
#  </datafield>
#  <datafield ind1="4" ind2=" " tag="856">
#   <subfield code="z">
#    kostenfrei
#   </subfield>
#  </datafield>
#  <datafield ind1="1" ind2=" " tag="883">
#   <subfield code="8">
#    1\p
#   </subfield>
#   <subfield code="a">
#    npi
#   </subfield>
#   <subfield code="d">
#    20240124
#   </subfield>
#   <subfield code="q">
#    DE-101
#   </subfield>
#   <subfield code="u">
#    https://d-nb.info/provenance/plan#npi
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="883">
#   <subfield code="8">
#    2\p
#   </subfield>
#   <subfield code="a">
#    cgwrk
#   </subfield>
#   <subfield code="d">
#    20240214
#   </subfield>
#   <subfield code="q">
#    DE-101
#   </subfield>
#   <subfield code="u">
#    https://d-nb.info/provenance/plan#cgwrk
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="883">
#   <subfield code="8">
#    3\p
#   </subfield>
#   <subfield code="a">
#    cgwrk
#   </subfield>
#   <subfield code="d">
#    20240214
#   </subfield>
#   <subfield code="q">
#    DE-101
#   </subfield>
#   <subfield code="u">
#    https://d-nb.info/provenance/plan#cgwrk
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="883">
#   <subfield code="8">
#    4\p
#   </subfield>
#   <subfield code="a">
#    cgwrk
#   </subfield>
#   <subfield code="d">
#    20240214
#   </subfield>
#   <subfield code="q">
#    DE-101
#   </subfield>
#   <subfield code="u">
#    https://d-nb.info/provenance/plan#cgwrk
#   </subfield>
#  </datafield>
#  <datafield ind1="0" ind2=" " tag="883">
#   <subfield code="8">
#    5\p
#   </subfield>
#   <subfield code="a">
#    emagnd
#   </subfield>
#   <subfield code="c">
#    0,12502
#   </subfield>
#   <subfield code="d">
#    20240124
#   </subfield>
#   <subfield code="q">
#    DE-101
#   </subfield>
#   <subfield code="u">
#    https://d-nb.info/provenance/plan#emagnd
#   </subfield>
#  </datafield>
#  <datafield ind1="0" ind2=" " tag="883">
#   <subfield code="8">
#    6\p
#   </subfield>
#   <subfield code="a">
#    emagnd
#   </subfield>
#   <subfield code="c">
#    0,10791
#   </subfield>
#   <subfield code="d">
#    20240124
#   </subfield>
#   <subfield code="q">
#    DE-101
#   </subfield>
#   <subfield code="u">
#    https://d-nb.info/provenance/plan#emagnd
#   </subfield>
#  </datafield>
#  <datafield ind1="0" ind2=" " tag="883">
#   <subfield code="8">
#    7\p
#   </subfield>
#   <subfield code="a">
#    emakn
#   </subfield>
#   <subfield code="c">
#    0,16355
#   </subfield>
#   <subfield code="d">
#    20240124
#   </subfield>
#   <subfield code="q">
#    DE-101
#   </subfield>
#   <subfield code="u">
#    https://d-nb.info/provenance/plan#emakn
#   </subfield>
#  </datafield>
#  <datafield ind1="0" ind2=" " tag="883">
#   <subfield code="8">
#    8\p
#   </subfield>
#   <subfield code="a">
#    emasg
#   </subfield>
#   <subfield code="c">
#    0,75848
#   </subfield>
#   <subfield code="d">
#    20240124
#   </subfield>
#   <subfield code="q">
#    DE-101
#   </subfield>
#   <subfield code="u">
#    https://d-nb.info/provenance/plan#emasg
#   </subfield>
#  </datafield>
#  <datafield ind1="r" ind2=" " tag="925">
#   <subfield code="a">
#    ro
#   </subfield>
#   <subfield code="a">
#    rh
#   </subfield>
#  </datafield>
#  <datafield ind1=" " ind2=" " tag="927">
#   <subfield code="a">
#    344162311
#   </subfield>
#  </datafield>
# </record>

# %% [markdown]
# ## Suche nach benötigten Informationen in den einzelnen Datensätzen:

# %%
#Funktion für Titeldaten in MARC21

def parse_record_marc(item):

    ns = {"marc":"http://www.loc.gov/MARC21/slim"}
    xml = ET.fromstring(unicodedata.normalize("NFC", str(item)))
    
    #idn
    idn = xml.findall("marc:controlfield[@tag = '001']", namespaces=ns)
    try:
        idn = idn[0].text
    except:
        idn = 'N/A' 
        
    
    #Titel 
    title = xml.findall("marc:datafield[@tag = '245']/marc:subfield[@code = 'a']", namespaces=ns)
    title2 = xml.findall("marc:datafield[@tag = '245']/marc:subfield[@code = 'b']", namespaces=ns)
    
    if title and not title2:
        titletext = title[0].text
    elif title and title2:     
        titletext = title[0].text + " " + title2[0].text   #Hier wird extra nur mit einem Leerzeichen getrennt statt eines Separators
    else:
        titletext = "N/A"
    
    
    #date
    date = xml.findall("marc:datafield[@tag = '264']/marc:subfield[@code = 'c']", namespaces=ns)
    date2 = xml.findall("marc:controlfield[@tag = '008']", namespaces=ns)
    if date:
        date = date[0].text
    elif date2:
        date = date2[0].text
        date = date[7:11]
    else:    
        date = 'N/A'
          
    #lang:
    lang = xml.findall("marc:datafield[@tag = '041']/marc:subfield[@code = 'a']", namespaces=ns)
    try:
        lang = lang[0].text
    except:
        lang = 'N/A'
    
    
    #URN: 
    urn = "N/A"
    for urn in xml.findall("marc:datafield[@tag = '024']/marc:subfield[@code = 'a']", namespaces=ns):
        if urn.text.startswith("urn:nbn"):
            urn = urn.text
        else: 
            urn = "N/A"
    
    
    meta_dict = {"idn":idn, "title": titletext, "date":date, "lang":lang, "urn":urn} 
               
    return meta_dict

# %%
output = [parse_record_marc(record) for record in myquery]

# %%
df = pd.DataFrame(output)
df
# Out:
#               idn                                              title  date  \
# 0      1285990005  2020 Das Jahr, das die Welt veränderte Der ame...  2024
# 1      1317002237  Ängste der Allgemeinbevölkerung in Zeiten der ...  2024
# 2      1319076106  Aufbau eines Key Account Managements in der To...  2024
# 3      1319076114  Aufbau eines Key Account Managements in der To...  2024
# 4      1315575361  Auswirkungen der Corona-Pandemie auf die Ausbi...  2024
# ...           ...                                                ...   ...
# 11363  129882589X                  Zwei Nachbarländer, eine Pandemie  2023
# 11364  1232892661  Zwei Runden gehen an Corona – aber die Urologi...  2021
# 11365  1307057543  Zwischen Arbeitserleichterung und De-Professio...  2023
# 11366  1241532591  Zwischen Pandemie und Wahlkampf: Verhältnismäß...  2021
# 11367  1280224673                                     Zwischenbilanz  2022
#
#       lang                                      urn
# 0      ger                                      N/A
# 1      ger         urn:nbn:de:bsz:14-qucosa2-890970
# 2      ger  urn:nbn:de:101:1-2024021302301350289147
# 3      ger  urn:nbn:de:101:1-2024021302302274697630
# 4      ger  urn:nbn:de:101:1-2024011102383134159187
# ...    ...                                      ...
# 11363  ger  urn:nbn:de:101:1-2023080821170040558967
# 11364  ger  urn:nbn:de:101:1-2021050520504432857162
# 11365  ger  urn:nbn:de:101:1-2023102409011131884864
# 11366  ger  urn:nbn:de:101:1-2021092021390437649681
# 11367  ger  urn:nbn:de:101:1-2023020621192547661605
#
# [11368 rows x 5 columns]

# %%
df.to_hdf("pandemie_titeldaten.h5", key="df")
